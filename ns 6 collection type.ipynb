# %%
var_1 = 1 
var_2 = 'any text'
var_3 = True

# %%
ls1 = []
type(ls1)
print(type(ls1))
# Out:
# <class 'list'>

# %%
ls2 = list()
print(type(ls2))
# Out:
# <class 'list'>

# %%
ls1
# Out:
# []

# %%
ls2
# Out:
# []

# %%
lis3 = ['h', 'a', 'p', 'p', 'y']
word = 'happy'
lis4 = list(word)
print(lis3, lis4, sep='\n')
# Out:
# ['h', 'a', 'p', 'p', 'y']
# ['h', 'a', 'p', 'p', 'y']

# %%
num = '123'
lis5 = list(num)
lis5
# Out:
# ['1', '2', '3']

# %%
num = 123 #integar tek bi karakter ifade ettiği için listelenecek hiç bir şey olmaz ve hata verir
lis5 = list(num)
lis5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-871ba223cdac> in <module>()
#       1 num = 123
# ----> 2 lis5 = list(num)
#       3 lis5
#
# TypeError: 'int' object is not iterable

# %%
num = 28.9 #'float' object is not iterable
lis5 = list(num)
lis5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-1d3cae13bfc4> in <module>()
#       1 num = 28.9
# ----> 2 lis5 = list(num)
#       3 lis5
#
# TypeError: 'float' object is not iterable

# %%
num = (28.9) #float sorunu böyle çözeriz
lis5 = list(str(num))
lis5
# Out:
# ['2', '8', '.', '9']

# %%
num = 28.9 20 + 8 +0.9
lis5 = list(num)
lis5
# Out:
#   File "<ipython-input-16-c45beba4f054>", line 1
#     num = 28.9 20 + 8 +0.9
#                 ^
# SyntaxError: invalid syntax

# %%
ls6 = [1]
ls7 = [21.7]

# %%
country = ['USA', 'Brasil', 'UK', 'Germany', 'Turkey', 'New Zelland']
print(country)
# Out:
# ['USA', 'Brasil', 'UK', 'Germany', 'Turkey', 'New Zelland']

# %%
ls8= [1, 2, 3, 4, 5]
ls8
# Out:
# [1, 2, 3, 4, 5]

# %%
string_1 = 'abc'
string_2 = 'bvd'
newlist_4 = list(string_1)
print(newlist_4)
#?????????????????????????????????????????
# Out:
# ['a', 'b', 'c']

# %%
my_list = ["josep", "clarusway", 2020] # bir liste birden fazla veri tipini bünyesinde barındırır
new_list1 = list(my_list)
new_list2 = [my_list]
print(new_list1)
print(len(new_list1))
print(new_list2)
print(len(new_list2))
# Out:
# ['josep', 'clarusway', 2020]
# 3
# [['josep', 'clarusway', 2020]]
# 1

# %%
numbers = [1, 4, 7]
numbers.append(9)
numbers.append('9')
print(numbers) #listeler değişebilirdir append ile değiştirince artık değişmiş olur
# Out:
# [1, 4, 7, 9, '9']

# %%
empty_lst = []
empty_lst.append(6666)
empty_lst.append('Multiverse')
empty_lst.append([0])   #append in tek eleman eklediğini unutmayalım
print(empty_lst)
# Out:
# [6666, 'Multiverse', [0]]

# %%
mixed_list = [11, 'Joseph', False, 3.14, None, [1, 2, 3, [4, 5, 6]]]
list(mixed_list)
# Out:
# [11, 'Joseph', False, 3.14, None, [1, 2, 3, [4, 5, 6]]]

# %%
lis9 = list(mixed_list)
lis9
# Out:
# [11, 'Joseph', False, 3.14, None, [1, 2, 3, [4, 5, 6]]]

# %%
lis10 = lis9
lis10
# Out:
# [11, 'Joseph', False, 3.14, None, [1, 2, 3, [4, 5, 6]]]

# %%
# how to create an empty list
empty_list_1 = []
empty_list_2 = list()

# %%
empty_list = []
print(empty_list, len(empty_list), sep = '\n')
empty_list.append(6666)
print(empty_list, len(empty_list), sep = '\n')
empty_list.append('Multiverse')
print(empty_list, len(empty_list), sep = '\n')
empty_list.append([0])   
print(empty_list, len(empty_list), sep = '\n')
# Out:
# []
# 0
# [6666]
# 1
# [6666, 'Multiverse']
# 2
# [6666, 'Multiverse', [0]]
# 3

# %%
city = ['New york', 'London', 'Istanbul', 'Seoul', 'Sydney']
city.append('Addis Ababa')

print(city)
# Out:
# ['New york', 'London', 'Istanbul', 'Seoul', 'Sydney', 'Addis Ababa']

# %%
ints = [1, 2, 3, 4, 5] # Rename "list" to "ints"
myrange = list(range(1, 10))

for number in ints: # Renamed "list" to "ints"
    if number in myrange:
        print(number, 'is between 1 and 10')
# Out:
# 1 is between 1 and 10
# 2 is between 1 and 10
# 3 is between 1 and 10
# 4 is between 1 and 10
# 5 is between 1 and 10

# %%
numbers= []
numbers.append(1)
numbers.append(2)
numbers.append(3)
numbers.append(4)
print(numbers)
# Out:
# [1, 2, 3, 4]

# %%
ls11 = []
ls11.append([1,2,3])
ls11
# Out:
# [[1, 2, 3]]

# %%
ls11 = []
ls12 = [1,2,3,4,5,6]
ls11.append(ls12)
ls11
# Out:
# [[1, 2, 3, 4, 5, 6]]

# %%
city = ['New york', 'London', 'Istanbul', 'Seoul', 'Sydney']
city.insert(2, 'Addis Ababa')

print(city)
# Out:
# ['New york', 'London', 'Addis Ababa', 'Istanbul', 'Seoul', 'Sydney']

# %%
city = ['New york', 'London', 'Istanbul', 'Seoul', 'Sydney']
city.insert('Addis Ababa')

print(city)  #index number olmadan hata verir
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-79c9f3038a53> in <module>()
#       1 city = ['New york', 'London', 'Istanbul', 'Seoul', 'Sydney']
# ----> 2 city.insert('Addis Ababa')
#       3
#       4 print(city)
#
# TypeError: insert() takes exactly 2 arguments (1 given)

# %%
lis13 = [1, 2, 3, 4]
lis13.insert(4, 5)
lis13
# Out:
# [1, 2, 3, 4, 5]

# %%
lis13 = [1, 2, 3, 4]
lis13.insert(5, 5) #normalde listemizde index n 5 yok ama önemli değil sonuna ekler
lis13.insert(-1, 7) #eksili sayı gelince sağa değil sola ekler
lis13
# Out:
# [1, 2, 3, 4, 7, 5]

# %%
lis13[4]
# Out:
# 7

# %%
lis13[-1]
# Out:
# 5

# %%
list3=[1,2,4]
list3.insert(list3[-1],5)   #yukarıdakinden farkı -1 için () yerine [] kullanmış olması
list3
# Out:
# [1, 2, 4, 5]

# %%
lis15 = [1,3,3,4,5,6,6,7,4,3,4,6,6,4,4,654,7,589,6,]
len(lis15)
# Out:
# 19

# %%
lis15 = [1,3,3,4,5,6,6,7,4,3,4,6,6,4,4,654,7,589,6,]
lis15.insert(19, 1453)
lis15
# Out:
# [1, 3, 3, 4, 5, 6, 6, 7, 4, 3, 4, 6, 6, 4, 4, 654, 7, 589, 6, 1453]

# %%
numbers = [1, 4, 7, 9]
numbers.remove(7)
print(numbers)
# Out:
# [1, 4, 9]

# %%
lis16 = [1,3,3,4,5,6,6,7,4,3,4,6,6,4,4,654,7,589,6,]
lis16.sort()  # alfabetik sıraya göre sırala demek buraya harflerde koyabilirdim 
# ama ab b ac c gibi harfler koyarsam ab ac b c olarak sıralacak ilk harfi alfabede önce olduğu için
print(lis16)
# Out:
# [1, 3, 3, 3, 4, 4, 4, 4, 4, 5, 6, 6, 6, 6, 6, 7, 7, 589, 654]

# %%
mix_list = ['d', 1, 'a' 7]
mix_list.sort()
print(mix_list)  #karakterler farklı olduğu için hata verdi
# Out:
#   File "<ipython-input-79-fe3f5dcd7cdc>", line 1
#     mix_list = ['d', 1, 'a' 7]
#                             ^
# SyntaxError: invalid syntax

# %%
list_1 = ["one", "four", "nine"]
list_1.sort()
list_1
# Out:
# ['four', 'nine', 'one']

# %%
list_2 = [True, False]
list_2.sort()
list_2
# Out:
# [False, True]

# %%
list
